# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/diabetes-dataset/diabetes.csv

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Data Preprocessing

# %%
diabetes_data = pd.read_csv("/kaggle/input/diabetes-dataset/diabetes.csv")

# %%
diabetes_data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_data.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
# Seperating features and labels

X = diabetes_data.drop(columns = 'Outcome', axis = 1)
Y = diabetes_data['Outcome']

# %% [markdown]
# #### Data Standardization

# %%
Scaler = StandardScaler()
Scaler.fit(X)
X = Scaler.transform(X)

# %%
X
# Out:
# array([[ 0.63994726,  0.84832379,  0.14964075, ...,  0.20401277,
#          0.46849198,  1.4259954 ],
#        [-0.84488505, -1.12339636, -0.16054575, ..., -0.68442195,
#         -0.36506078, -0.19067191],
#        [ 1.23388019,  1.94372388, -0.26394125, ..., -1.10325546,
#          0.60439732, -0.10558415],
#        ...,
#        [ 0.3429808 ,  0.00330087,  0.14964075, ..., -0.73518964,
#         -0.68519336, -0.27575966],
#        [-0.84488505,  0.1597866 , -0.47073225, ..., -0.24020459,
#         -0.37110101,  1.17073215],
#        [-0.84488505, -0.8730192 ,  0.04624525, ..., -0.20212881,
#         -0.47378505, -0.87137393]])

# %%
# Train Test Split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, stratify= Y, random_state = 2)
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (768, 8) (614, 8) (154, 8)

# %% [markdown]
# ## Model Training

# %%
model = svm.SVC(kernel = 'linear')

# %%
model.fit(X_train, Y_train)
# Out:
# SVC(kernel='linear')

# %%
# Evaluation
predicted_Y = model.predict(X_test)
test_accuracy = accuracy_score(Y_test, predicted_Y)
print(test_accuracy)
# Out:
# 0.7727272727272727

# %% [markdown]
# ### DL based model

# %%
from tensorflow import keras
from tensorflow.keras import layers

# %%
model = keras.Sequential([
    layers.Dense(units = 32, activation = 'relu', input_shape= [8]),
    layers.Dense(units = 32, activation = 'relu'),
    layers.Dense(units = 1, activation = 'sigmoid')
])

# %%
model.compile(
    loss = 'binary_crossentropy',
    optimizer = 'adam',
    metrics = ['binary_accuracy']
)

# %%
model.fit( 
    X_train, Y_train,
    validation_data = (X_test, Y_test),
    batch_size = 32,
    epochs = 100
)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 1s 12ms/step - loss: 0.6968 - binary_accuracy: 0.5098 - val_loss: 0.6510 - val_binary_accuracy: 0.7078
# Epoch 2/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6160 - binary_accuracy: 0.7345 - val_loss: 0.5964 - val_binary_accuracy: 0.7662
# Epoch 3/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5607 - binary_accuracy: 0.7557 - val_loss: 0.5610 - val_binary_accuracy: 0.7727
# Epoch 4/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5212 - binary_accuracy: 0.7752 - val_loss: 0.5384 - val_binary_accuracy: 0.7532
# Epoch 5/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4920 - binary_accuracy: 0.7736 - val_loss: 0.5251 - val_binary_accuracy: 0.7727
# Epoch 6/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4731 - binary_accuracy: 0.7850 - val_loss: 0.5216 - val_binary_accuracy: 0.7662
# Epoch 7/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4618 - binary_accuracy: 0.7752 - val_loss: 0.5181 - val_binary_accuracy: 0.7792
# Epoch 8/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4512 - binary_accuracy: 0.7818 - val_loss: 0.5206 - val_binary_accuracy: 0.7857
# Epoch 9/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4454 - binary_accuracy: 0.7834 - val_loss: 0.5190 - val_binary_accuracy: 0.7727
# Epoch 10/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4393 - binary_accuracy: 0.7866 - val_loss: 0.5215 - val_binary_accuracy: 0.7727
# Epoch 11/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4360 - binary_accuracy: 0.7883 - val_loss: 0.5208 - val_binary_accuracy: 0.7662
# Epoch 12/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4326 - binary_accuracy: 0.7915 - val_loss: 0.5206 - val_binary_accuracy: 0.7597
# Epoch 13/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4289 - binary_accuracy: 0.7932 - val_loss: 0.5265 - val_binary_accuracy: 0.7727
# Epoch 14/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4252 - binary_accuracy: 0.7915 - val_loss: 0.5323 - val_binary_accuracy: 0.7727
# Epoch 15/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4227 - binary_accuracy: 0.7948 - val_loss: 0.5318 - val_binary_accuracy: 0.7792
# Epoch 16/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4204 - binary_accuracy: 0.7980 - val_loss: 0.5313 - val_binary_accuracy: 0.7727
# Epoch 17/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4192 - binary_accuracy: 0.7948 - val_loss: 0.5330 - val_binary_accuracy: 0.7727
# Epoch 18/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4161 - binary_accuracy: 0.8013 - val_loss: 0.5377 - val_binary_accuracy: 0.7662
# Epoch 19/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4147 - binary_accuracy: 0.8013 - val_loss: 0.5372 - val_binary_accuracy: 0.7662
# Epoch 20/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4122 - binary_accuracy: 0.8013 - val_loss: 0.5356 - val_binary_accuracy: 0.7597
# Epoch 21/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4100 - binary_accuracy: 0.8046 - val_loss: 0.5369 - val_binary_accuracy: 0.7597
# Epoch 22/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4087 - binary_accuracy: 0.8062 - val_loss: 0.5453 - val_binary_accuracy: 0.7597
# Epoch 23/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4097 - binary_accuracy: 0.8046 - val_loss: 0.5374 - val_binary_accuracy: 0.7597
# Epoch 24/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4055 - binary_accuracy: 0.8062 - val_loss: 0.5374 - val_binary_accuracy: 0.7597
# Epoch 25/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4043 - binary_accuracy: 0.8078 - val_loss: 0.5402 - val_binary_accuracy: 0.7532
# Epoch 26/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4022 - binary_accuracy: 0.8078 - val_loss: 0.5463 - val_binary_accuracy: 0.7597
# Epoch 27/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4010 - binary_accuracy: 0.8127 - val_loss: 0.5448 - val_binary_accuracy: 0.7532
# Epoch 28/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3987 - binary_accuracy: 0.8094 - val_loss: 0.5476 - val_binary_accuracy: 0.7468
# Epoch 29/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3996 - binary_accuracy: 0.8062 - val_loss: 0.5440 - val_binary_accuracy: 0.7468
# Epoch 30/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3962 - binary_accuracy: 0.8062 - val_loss: 0.5480 - val_binary_accuracy: 0.7532
# Epoch 31/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3941 - binary_accuracy: 0.8062 - val_loss: 0.5466 - val_binary_accuracy: 0.7532
# Epoch 32/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3928 - binary_accuracy: 0.8111 - val_loss: 0.5490 - val_binary_accuracy: 0.7403
# Epoch 33/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3917 - binary_accuracy: 0.8111 - val_loss: 0.5520 - val_binary_accuracy: 0.7468
# Epoch 34/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3888 - binary_accuracy: 0.8094 - val_loss: 0.5499 - val_binary_accuracy: 0.7597
# Epoch 35/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3883 - binary_accuracy: 0.8127 - val_loss: 0.5529 - val_binary_accuracy: 0.7597
# Epoch 36/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3873 - binary_accuracy: 0.8127 - val_loss: 0.5583 - val_binary_accuracy: 0.7532
# Epoch 37/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3848 - binary_accuracy: 0.8143 - val_loss: 0.5544 - val_binary_accuracy: 0.7597
# Epoch 38/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3829 - binary_accuracy: 0.8160 - val_loss: 0.5559 - val_binary_accuracy: 0.7597
# Epoch 39/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3819 - binary_accuracy: 0.8192 - val_loss: 0.5598 - val_binary_accuracy: 0.7468
# Epoch 40/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3792 - binary_accuracy: 0.8192 - val_loss: 0.5614 - val_binary_accuracy: 0.7532
# Epoch 41/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3774 - binary_accuracy: 0.8241 - val_loss: 0.5628 - val_binary_accuracy: 0.7468
# Epoch 42/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3766 - binary_accuracy: 0.8257 - val_loss: 0.5656 - val_binary_accuracy: 0.7597
# Epoch 43/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3747 - binary_accuracy: 0.8241 - val_loss: 0.5712 - val_binary_accuracy: 0.7468
# Epoch 44/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3745 - binary_accuracy: 0.8274 - val_loss: 0.5696 - val_binary_accuracy: 0.7597
# Epoch 45/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3711 - binary_accuracy: 0.8257 - val_loss: 0.5656 - val_binary_accuracy: 0.7532
# Epoch 46/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3697 - binary_accuracy: 0.8339 - val_loss: 0.5668 - val_binary_accuracy: 0.7532
# Epoch 47/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3685 - binary_accuracy: 0.8274 - val_loss: 0.5764 - val_binary_accuracy: 0.7532
# Epoch 48/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3677 - binary_accuracy: 0.8241 - val_loss: 0.5757 - val_binary_accuracy: 0.7403
# Epoch 49/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3649 - binary_accuracy: 0.8274 - val_loss: 0.5734 - val_binary_accuracy: 0.7532
# Epoch 50/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3636 - binary_accuracy: 0.8339 - val_loss: 0.5757 - val_binary_accuracy: 0.7532
# Epoch 51/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3618 - binary_accuracy: 0.8371 - val_loss: 0.5777 - val_binary_accuracy: 0.7468
# Epoch 52/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3598 - binary_accuracy: 0.8322 - val_loss: 0.5829 - val_binary_accuracy: 0.7532
# Epoch 53/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3598 - binary_accuracy: 0.8306 - val_loss: 0.5869 - val_binary_accuracy: 0.7532
# Epoch 54/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3574 - binary_accuracy: 0.8355 - val_loss: 0.5866 - val_binary_accuracy: 0.7338
# Epoch 55/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3564 - binary_accuracy: 0.8355 - val_loss: 0.5870 - val_binary_accuracy: 0.7338
# Epoch 56/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3536 - binary_accuracy: 0.8469 - val_loss: 0.5843 - val_binary_accuracy: 0.7468
# Epoch 57/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3524 - binary_accuracy: 0.8469 - val_loss: 0.5858 - val_binary_accuracy: 0.7468
# Epoch 58/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3510 - binary_accuracy: 0.8371 - val_loss: 0.5930 - val_binary_accuracy: 0.7468
# Epoch 59/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3496 - binary_accuracy: 0.8436 - val_loss: 0.5930 - val_binary_accuracy: 0.7338
# Epoch 60/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3477 - binary_accuracy: 0.8469 - val_loss: 0.5891 - val_binary_accuracy: 0.7338
# Epoch 61/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3463 - binary_accuracy: 0.8469 - val_loss: 0.5934 - val_binary_accuracy: 0.7403
# Epoch 62/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3442 - binary_accuracy: 0.8502 - val_loss: 0.5987 - val_binary_accuracy: 0.7338
# Epoch 63/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3438 - binary_accuracy: 0.8420 - val_loss: 0.5979 - val_binary_accuracy: 0.7403
# Epoch 64/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3415 - binary_accuracy: 0.8404 - val_loss: 0.6024 - val_binary_accuracy: 0.7338
# Epoch 65/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3405 - binary_accuracy: 0.8502 - val_loss: 0.6032 - val_binary_accuracy: 0.7403
# Epoch 66/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3410 - binary_accuracy: 0.8453 - val_loss: 0.6075 - val_binary_accuracy: 0.7338
# Epoch 67/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3380 - binary_accuracy: 0.8518 - val_loss: 0.6097 - val_binary_accuracy: 0.7403
# Epoch 68/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3367 - binary_accuracy: 0.8453 - val_loss: 0.6114 - val_binary_accuracy: 0.7468
# Epoch 69/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3367 - binary_accuracy: 0.8469 - val_loss: 0.6066 - val_binary_accuracy: 0.7532
# Epoch 70/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3343 - binary_accuracy: 0.8567 - val_loss: 0.6051 - val_binary_accuracy: 0.7468
# Epoch 71/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3333 - binary_accuracy: 0.8518 - val_loss: 0.6118 - val_binary_accuracy: 0.7532
# Epoch 72/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3332 - binary_accuracy: 0.8534 - val_loss: 0.6172 - val_binary_accuracy: 0.7403
# Epoch 73/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3315 - binary_accuracy: 0.8632 - val_loss: 0.6131 - val_binary_accuracy: 0.7403
# Epoch 74/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3297 - binary_accuracy: 0.8599 - val_loss: 0.6196 - val_binary_accuracy: 0.7468
# Epoch 75/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3266 - binary_accuracy: 0.8550 - val_loss: 0.6245 - val_binary_accuracy: 0.7403
# Epoch 76/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3258 - binary_accuracy: 0.8599 - val_loss: 0.6239 - val_binary_accuracy: 0.7403
# Epoch 77/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3237 - binary_accuracy: 0.8616 - val_loss: 0.6260 - val_binary_accuracy: 0.7403
# Epoch 78/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3222 - binary_accuracy: 0.8632 - val_loss: 0.6260 - val_binary_accuracy: 0.7468
# Epoch 79/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3237 - binary_accuracy: 0.8632 - val_loss: 0.6287 - val_binary_accuracy: 0.7532
# Epoch 80/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3186 - binary_accuracy: 0.8616 - val_loss: 0.6325 - val_binary_accuracy: 0.7468
# Epoch 81/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3186 - binary_accuracy: 0.8681 - val_loss: 0.6375 - val_binary_accuracy: 0.7468
# Epoch 82/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3174 - binary_accuracy: 0.8713 - val_loss: 0.6341 - val_binary_accuracy: 0.7662
# Epoch 83/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3158 - binary_accuracy: 0.8681 - val_loss: 0.6332 - val_binary_accuracy: 0.7468
# Epoch 84/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3131 - binary_accuracy: 0.8681 - val_loss: 0.6395 - val_binary_accuracy: 0.7403
# Epoch 85/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3146 - binary_accuracy: 0.8664 - val_loss: 0.6498 - val_binary_accuracy: 0.7532
# Epoch 86/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3116 - binary_accuracy: 0.8730 - val_loss: 0.6467 - val_binary_accuracy: 0.7468
# Epoch 87/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3102 - binary_accuracy: 0.8697 - val_loss: 0.6482 - val_binary_accuracy: 0.7403
# Epoch 88/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3094 - binary_accuracy: 0.8697 - val_loss: 0.6523 - val_binary_accuracy: 0.7468
# Epoch 89/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3065 - binary_accuracy: 0.8697 - val_loss: 0.6498 - val_binary_accuracy: 0.7338
# Epoch 90/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3076 - binary_accuracy: 0.8730 - val_loss: 0.6432 - val_binary_accuracy: 0.7532
# Epoch 91/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3048 - binary_accuracy: 0.8730 - val_loss: 0.6552 - val_binary_accuracy: 0.7468
# Epoch 92/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3044 - binary_accuracy: 0.8746 - val_loss: 0.6465 - val_binary_accuracy: 0.7468
# Epoch 93/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3028 - binary_accuracy: 0.8730 - val_loss: 0.6509 - val_binary_accuracy: 0.7532
# Epoch 94/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.3012 - binary_accuracy: 0.8795 - val_loss: 0.6551 - val_binary_accuracy: 0.7532
# Epoch 95/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2984 - binary_accuracy: 0.8762 - val_loss: 0.6534 - val_binary_accuracy: 0.7468
# Epoch 96/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2993 - binary_accuracy: 0.8746 - val_loss: 0.6565 - val_binary_accuracy: 0.7597
# Epoch 97/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2951 - binary_accuracy: 0.8795 - val_loss: 0.6664 - val_binary_accuracy: 0.7597
# Epoch 98/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2943 - binary_accuracy: 0.8795 - val_loss: 0.6688 - val_binary_accuracy: 0.7597
# Epoch 99/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2930 - binary_accuracy: 0.8762 - val_loss: 0.6696 - val_binary_accuracy: 0.7532
# Epoch 100/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.2906 - binary_accuracy: 0.8779 - val_loss: 0.6697 - val_binary_accuracy: 0.7532
